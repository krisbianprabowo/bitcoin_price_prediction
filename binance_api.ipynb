# %%
import requests
import jsonify
import pandas as pd
import numpy as np

market = 'BTCUSDT'
tick_interval = '1h'
startTime = 1648771200000
startTime_2 = 1612137600000         # 1 Februari 2021
startTime_3 = 1577836800000         # 1 Januari 2020
endTime = 1649363212000             # 1 April 2022
appended_data = []
df = pd.DataFrame()
while startTime_3<endTime:
    url = 'https://api.binance.me/api/v3/klines?symbol='+market+'&interval='+tick_interval+'&limit=1000'+'&startTime='+str(startTime)+'&endTime='+str(endTime)
    data = requests.get(url).json()
    df = pd.concat([df, pd.DataFrame(data)])
    startTime_3 = data[-1][0] + 3600000

# %%
df[0].is_unique
# Out:
# True

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                 0               1               2               3   \
# 0    1648771200000  45510.35000000  45644.86000000  45351.73000000
# 1    1648774800000  45542.16000000  45542.17000000  44868.00000000
# 2    1648778400000  44923.77000000  45049.03000000  44200.00000000
# 3    1648782000000  44392.71000000  44599.99000000  44273.44000000
# 4    1648785600000  44599.98000000  44780.01000000  44547.11000000
# ..             ...             ...             ...             ...
# 160  1649347200000  43331.82000000  43497.28000000  43266.68000000
# 161  1649350800000  43494.00000000  43695.12000000  43472.05000000
# 162  1649354400000  43657.68000000  43819.99000000  43514.01000000
# 163  1649358000000  43702.96000000  43772.52000000  43375.36000000
# 164  1649361600000  43388.93000000  43477.53000000  43376.23000000
#
#                  4              5              6                   7       8   \
# 0    45541.50000000  1838.20071000  1648774799999   83712318.65105210   51792
# 1    44923.77000000  4127.99675000  1648778399999  186365597.08843290   76504
# 2    44392.71000000  5752.16535000  1648781999999  256708976.05610860  108602
# 3    44599.98000000  2692.58541000  1648785599999  119680879.01506450   60370
# 4    44642.44000000  1723.22376000  1648789199999   76979363.54545760   47181
# ..              ...            ...            ...                 ...     ...
# 160  43494.00000000  1567.91119000  1649350799999   68051116.24963570   41108
# 161  43657.68000000  1634.74431000  1649354399999   71287148.92045410   40257
# 162  43702.95000000  1635.98052000  1649357999999   71427353.73552800   41133
# 163  43388.92000000  1261.65436000  1649361599999   54962630.74768230   33162
# 164  43477.53000000   330.46357000  1649365199999   14351984.31212300   11500
#
#                 9                   10 11
# 0     940.42832000   42827268.69736760  0
# 1    1892.75020000   85445203.53523660  0
# 2    2428.04740000  108410905.37738280  0
# 3    1445.07602000   64230409.86632710  0
# 4     892.21570000   39858911.62263320  0
# ..             ...                 ... ..
# 160   726.86929000   31547857.55198580  0
# 161   886.78588000   38668978.34579440  0
# 162   824.43614000   35996767.78453120  0
# 163   582.05520000   25350216.86415450  0
# 164   202.39194000    8790088.98243990  0
#
# [165 rows x 12 columns]

# %%
df.to_csv('historical_prices/'+market+'_'+tick_interval+'_2022_2022.csv')

# %%
# import requests
# import jsonify
# import pandas as pd
# import numpy as np

# market = 'BTCUSDT'
# tick_interval = '1h'
# startTime = 1502942400000
# endTime = 1648681200000
# appended_data = []
# dfdup = pd.DataFrame()
# while startTime<endTime:
#     url = 'https://api.binance.me/api/v3/klines?symbol='+market+'&interval='+tick_interval+'&limit=1000'+'&startTime='+str(startTime)+'&endTime='+str(endTime)
#     data = requests.get(url).json()
#     dfdup = pd.concat([df, pd.DataFrame(data)])
#     startTime = data[-1][0]

# %%
url = 'https://api.binance.me/api/v3/klines?symbol='+market+'&interval='+tick_interval+'&limit=2'
data = requests.get(url).json()
data
# Out:
# [[1648789200000,
#   '44642.44000000',
#   '44789.99000000',
#   '44583.23000000',
#   '44646.16000000',
#   '1456.34706000',
#   1648792799999,
#   '65073274.73490560',
#   38119,
#   '753.83435000',
#   '33682362.21035760',
#   '0'],
#  [1648792800000,
#   '44646.15000000',
#   '44848.44000000',
#   '44567.94000000',
#   '44813.93000000',
#   '1267.14958000',
#   1648796399999,
#   '56673782.86542240',
#   37255,
#   '678.72691000',
#   '30359486.07730340',
#   '0']]

# %%
import requests
import jsonify
import pandas as pd
import numpy as np

market = 'BTCUSDT'
tick_interval = '1d'
startTime = 1502928000000           # 17 Agustus 2017
endTime = 1648789200000             # 1 April 2022
appended_data = []
df = pd.DataFrame()
while startTime<endTime:
    url = 'https://api.binance.me/api/v3/klines?symbol='+market+'&interval='+tick_interval+'&limit=1000'+'&startTime='+str(startTime)+'&endTime='+str(endTime)
    data = requests.get(url).json()
    df = pd.concat([df, pd.DataFrame(data)])
    startTime = data[-1][0] + 86400000

# %%
df[0].is_unique
# Out:
# True

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#                  0               1               2               3   \
# 0     1502928000000   4261.48000000   4485.39000000   4200.74000000
# 1     1503014400000   4285.08000000   4371.52000000   3938.77000000
# 2     1503100800000   4108.37000000   4184.69000000   3850.00000000
# 3     1503187200000   4120.98000000   4211.08000000   4032.62000000
# 4     1503273600000   4069.13000000   4119.62000000   3911.79000000
# ...             ...             ...             ...             ...
# 1684  1648425600000  46827.76000000  48189.84000000  46663.56000000
# 1685  1648512000000  47122.21000000  48096.47000000  46950.85000000
# 1686  1648598400000  47434.79000000  47700.22000000  46445.42000000
# 1687  1648684800000  47067.99000000  47600.00000000  45200.00000000
# 1688  1648771200000  45510.35000000  45644.86000000  44200.00000000
#
#                   4               5              6                    7   \
# 0      4285.08000000    795.15037700  1503014399999     3454770.05073206
# 1      4108.37000000   1199.88826400  1503100799999     5086958.30617151
# 2      4139.98000000    381.30976300  1503187199999     1549483.73542151
# 3      4086.29000000    467.08302200  1503273599999     1930364.39032646
# 4      4016.00000000    691.74306000  1503359999999     2797231.71402728
# ...              ...             ...            ...                  ...
# 1684  47122.21000000  58949.26140000  1648511999999  2789898402.61657610
# 1685  47434.80000000  36772.28457000  1648598399999  1748600385.45023520
# 1686  47067.99000000  40947.20850000  1648684799999  1932152559.88311230
# 1687  45510.34000000  48645.12667000  1648771199999  2262485160.56858420
# 1688  44813.93000000  18857.66862000  1648857599999   845194191.95644370
#
#            8               9                    10              11
# 0        3427    616.24854100     2678216.40060401   8733.91139481
# 1        5233    972.86871000     4129123.31651808   9384.14140858
# 2        2153    274.33604200     1118001.87008735   9184.08552906
# 3        2321    376.79594700     1557401.33373730  10125.41408414
# 4        3972    557.35610700     2255662.55315837  11706.76997007
# ...       ...             ...                  ...             ...
# 1684  1498975  29097.75719000  1377280753.97272760               0
# 1685  1095678  18192.37420000   865179145.17564560               0
# 1686  1081607  20896.43399000   985946938.56827850               0
# 1687  1290541  22879.47328000  1064278670.64261090               0
# 1688   419823   9031.07890000   404814547.38660830               0
#
# [1689 rows x 12 columns]

# %%
df.to_csv('historical_prices/'+market+'_'+tick_interval+'_2017_2022.csv')

# %%
# dfdup.drop_duplicates(subset=0, keep='first', inplace=True)
# dfdup.reset_index(drop=True, inplace=True)
# df.reset_index(drop=True, inplace=True)
# for i, v in enumerate(dfdup.itertuples()):
#     if dfdup.iloc[i,0] != df.iloc[i,0]:
#         print('false')
